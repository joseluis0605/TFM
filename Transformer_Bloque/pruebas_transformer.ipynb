# %%
# prueba del transformer
import numpy as np
import torch  # libreria principal de python
import torch.nn as nn  # modulo para las redes neuronales
import torch.optim as optim  # modulo para algoritmos de optimizacion en redes neuronales
import torch.utils.data as data  # modulo para tratar con los datasets
import math  # operaciones matematicas
import copy  # para copiar objetos y estructuras
import  MultiHeadAttention
import FeedForward
import Transformer
import pandas as pd
import nltk
from sklearn.model_selection import train_test_split

# %%
src_vocab_size = 10000
tgt_vocab_size = 10000
d_model = 512
num_heads = 8
num_layers = 6
d_ff = 2048
max_seq_length = 100
dropout = 0.1

# %%
dataset = pd.read_csv("dataset_English-Spanish_Translation_Dataset.csv", sep=",", encoding="utf-8")

print("Mostramos contenido de las primeras 10 lineas")
dataset.head(10)
# Out:
# Mostramos contenido de las primeras 10 lineas
#   english     spanish
# 0     Go.         Ve.
# 1     Go.       Vete.
# 2     Go.       Vaya.
# 3     Go.     Váyase.
# 4     Hi.       Hola.
# 5    Run!     ¡Corre!
# 6    Run.     Corred.
# 7    Who?     ¿Quién?
# 8   Fire!     ¡Fuego!
# 9   Fire!  ¡Incendio!

# %%
print("Dimensiones del dataset de prueba")
dataset.shape
# Out:
# Dimensiones del dataset de prueba
# (118964, 2)

# %%
dataset.tail(10)
# Out:
#                                                   english  \
# 118954  You can't view Flash content on an iPad. Howev...
# 118955  A mistake young people often make is to start ...
# 118956  No matter how much you try to convince people ...
# 118957  In 1969, Roger Miller recorded a song called "...
# 118958  A child who is a native speaker usually knows ...
# 118959  There are four main causes of alcohol-related ...
# 118960  There are mothers and fathers who will lie awa...
# 118961  A carbon footprint is the amount of carbon dio...
# 118962  Since there are usually multiple websites on a...
# 118963  If you want to sound like a native speaker, yo...
#
#                                                   spanish
# 118954  No puedes ver contenido en Flash en un iPad. S...
# 118955  Un error que cometen a menudo los jóvenes es e...
# 118956  No importa cuánto insistas en convencer a la g...
# 118957  En 1969, Roger Miller grabó una canción llamad...
# 118958  Un niño que es hablante nativo normalmente sab...
# 118959  Hay cuatro causas principales de muertes relac...
# 118960  Hay madres y padres que se quedan despiertos d...
# 118961  Una huella de carbono es la cantidad de contam...
# 118962  Como suele haber varias páginas web sobre cual...
# 118963  Si quieres sonar como un hablante nativo, debe...

# %%
dataset.info
# Out:
# <bound method DataFrame.info of                                                   english  \
# 0                                                     Go.
# 1                                                     Go.
# 2                                                     Go.
# 3                                                     Go.
# 4                                                     Hi.
# ...                                                   ...
# 118959  There are four main causes of alcohol-related ...
# 118960  There are mothers and fathers who will lie awa...
# 118961  A carbon footprint is the amount of carbon dio...
# 118962  Since there are usually multiple websites on a...
# 118963  If you want to sound like a native speaker, yo...
#
#                                                   spanish
# 0                                                     Ve.
# 1                                                   Vete.
# 2                                                   Vaya.
# 3                                                 Váyase.
# 4                                                   Hola.
# ...                                                   ...
# 118959  Hay cuatro causas principales de muertes relac...
# 118960  Hay madres y padres que se quedan despiertos d...
# 118961  Una huella de carbono es la cantidad de contam...
# 118962  Como suele haber varias páginas web sobre cual...
# 118963  Si quieres sonar como un hablante nativo, debe...
#
# [118964 rows x 2 columns]>

# %%
# dividimos en conjunto de train y de test
x_train_ingles, x_test_ingles, y_train_ingles, y_test_ingles = train_test_split(dataset["english"], dataset["spanish"], random_state=42, test_size=0.2)

x_train_ingles.shape, y_train_ingles.shape, x_test_ingles.shape, y_test_ingles.shape
# Out:
# ((95171,), (95171,), (23793,), (23793,))

# %%
# vamos a preprocesar el texto, idioma si esta a true = español y si esta a false = ingles
def preprocesamiento_texto(texto, idioma: bool):
    texto = texto.lower()

    # si es español, ponemos etiqueta <esp>
    if idioma:
        texto = "<sos> <esp> " + texto + " <eos>"
    # si es en ingles, ponemos etiqueta <eng>
    else:
        texto = "<eng> " + texto 
        
    return texto

x_train_ingles = x_train_ingles.apply(preprocesamiento_texto, idioma= False)
y_train_spanish = y_train_ingles.apply(preprocesamiento_texto, idioma= True)

# %%
x_train_ingles.head(5)
# Out:
# 36040                     <eng> i have no choice at all.
# 5968                               <eng> i had to do it.
# 4653                                <eng> is this yours?
# 95794    <eng> the family had a hard time after the war.
# 72955            <eng> i want you to call off the fight.
# Name: english, dtype: object

# %%
y_train_spanish.head(5)
# Out:
# 36040    <sos> <esp> no tengo otra opción en absoluto.<...
# 5968                    <sos> <esp> tuve que hacerlo.<eos>
# 4653                       <sos> <esp> ¿es suyo esto?<eos>
# 95794    <sos> <esp> la familia atravesó por un mal tie...
# 72955      <sos> <esp> quiero que suspendas la pelea.<eos>
# Name: spanish, dtype: object

# %%
from nltk import word_tokenize

def tokenizar (texto):
    tokens = word_tokenize(texto)
    print(tokens)
    return tokens

x_train_ingles = x_train_ingles.apply(tokenizar)
# Out:
# ['<', 'eng', '>', 'i', 'have', 'no', 'choice', 'at', 'all', '.']
# ['<', 'eng', '>', 'i', 'had', 'to', 'do', 'it', '.']
# ['<', 'eng', '>', 'is', 'this', 'yours', '?']
# ['<', 'eng', '>', 'the', 'family', 'had', 'a', 'hard', 'time', 'after', 'the', 'war', '.']
# ['<', 'eng', '>', 'i', 'want', 'you', 'to', 'call', 'off', 'the', 'fight', '.']
# ['<', 'eng', '>', 'his', 'wish', 'is', 'to', 'go', 'to', 'america', '.']
# ['<', 'eng', '>', 'tom', 'is', 'mary', "'s", 'neighbor', '.']
# ['<', 'eng', '>', 'please', 'visit', 'me', 'tomorrow', '.']
# ['<', 'eng', '>', 'is', 'tom', 'always', 'like', 'this', '?']
# ['<', 'eng', '>', 'we', 'have', 'our', 'dinner', 'between', 'seven', 'and', 'seven-thirty', '.']
# ['<', 'eng', '>', 'i', "'ve", 'been', 'working', 'with', 'tom', 'for', 'three', 'months', '.']
# ['<', 'eng', '>', 'it', "'s", 'late', '.', 'i', 'have', 'to', 'go', '.']
# ['<', 'eng', '>', 'tom', 'has', 'no', 'sense', 'of', 'style', '.']
# ['<', 'eng', '>', 'i', 'regret', 'that', 'i', 'wasted', 'the', 'money', '.']
# ['<', 'eng', '>', 'do', 'you', 'miss', 'me', '?']
# ['<', 'eng', '>', 'my', 'mother', 'is', 'sick', 'in', 'bed', '.']
# ['<', 'eng', '>', 'of', 'course', ',', 'to', 'be', 'valuable', ',', 'an', 'old', 'carpet', 'must', 'be', 'in', 'good', 'condition', '.']
# ['<', 'eng', '>', 'can', 'you', 'explain', 'it', 'more', 'clearly', '?']
# ['<', 'eng', '>', 'the', 'lawyer', 'believed', 'in', 'his', 'client', "'s", 'innocence', '.']
# ['<', 'eng', '>', 'it', "'s", 'cold', 'outside', '.']
# ['<', 'eng', '>', 'the', 'soldier', 'took', 'shelter', 'in', 'the', 'foxhole', '.']
# ['<', 'eng', '>', 'can', 'you', 'at', 'least', 'pretend', 'you', 'want', 'to', 'be', 'here', '?']
# ['<', 'eng', '>', 'i', "'m", 'not', 'sure', 'what', "'s", 'wrong', '.', 'we', 'should', 'have', 'heard', 'from', 'him', 'by', 'now', '.']
# ['<', 'eng', '>', 'what', 'instruments', 'does', 'tom', 'play', '?']
# ['<', 'eng', '>', 'i', 'thought', 'tom', 'would', 'ask', 'mary', 'to', 'go', 'with', 'him', 'to', 'boston', '.']
# ['<', 'eng', '>', 'tom', 'is', 'broad-minded', '.']
# ['<', 'eng', '>', 'do', 'me', 'a', 'favor', 'by', 'switching', 'off', 'that', 'radio', '.']
# ['<', 'eng', '>', 'would', 'you', 'like', 'some', 'more', 'beef', '?']
# ['<', 'eng', '>', 'is', 'tom', 'trying', 'to', 'ruin', 'our', 'evening', '?']
# ['<', 'eng', '>', 'are', 'you', 'bald', '?']
# ['<', 'eng', '>', 'i', 'will', 'never', 'have', 'a', 'son', '.']
# ['<', 'eng', '>', 'follow', 'his', 'example', '.']
# ['<', 'eng', '>', 'you', 'can', 'make', 'a', 'cake', 'with', 'flour', ',', 'milk', 'and', 'an', 'egg', '.']
# ['<', 'eng', '>', 'tom', 'found', 'a', 'wallet', 'on', 'the', 'sidewalk', '.']
# ['<', 'eng', '>', 'i', 'participated', 'in', 'the', 'discussion', '.']
# ['<', 'eng', '>', 'a', 'man', "'s", 'body', 'dies', ',', 'but', 'his', 'soul', 'is', 'immortal', '.']
# ['<', 'eng', '>', 'that', "'s", 'amazing', '!']
# ['<', 'eng', '>', 'who', 'wrote', 'the', 'letter', '?']
# ['<', 'eng', '>', 'it', 'is', "n't", 'suitable', 'for', 'minors', '.']
# ['<', 'eng', '>', 'it', 'wo', "n't", 'be', 'long', 'before', 'we', 'can', 'travel', 'to', 'mars', '.']
# ['<', 'eng', '>', 'i', 'will', 'give', 'you', 'a', 'bicycle', 'for', 'your', 'birthday', '.']
# ['<', 'eng', '>', 'they', 'spent', 'the', 'entire', 'day', 'on', 'the', 'beach', '.']
# ['<', 'eng', '>', 'i', 'saw', 'his', 'face', 'in', 'the', 'dim', 'light', '.']
# ['<', 'eng', '>', 'he', 'made', 'his', 'son', 'a', 'chair', '.']
# ['<', 'eng', '>', 'tom', 'ate', 'everything', 'on', 'his', 'plate', '.']
# ['<', 'eng', '>', 'tom', 'did', 'his', 'best', ',', 'but', 'he', 'failed', '.']
# ['<', 'eng', '>', 'i', 'think', 'tom', 'is', 'a', 'liar', '.']
# ['<', 'eng', '>', 'is', 'your', 'husband', 'at', 'home', '?']
# ['<', 'eng', '>', 'tom', 'repacked', 'his', 'suitcase', '.']
# ['<', 'eng', '>', 'was', 'her', 'story', 'true', '?']
# ['<', 'eng', '>', 'somebody', 'must', 'care', 'for', 'the', 'patient', '.']
# ['<', 'eng', '>', 'i', 'would', 'do', 'anything', 'but', 'that', '.']
# ['<', 'eng', '>', 'you', 'have', 'twice', 'dared', 'to', 'contradict', 'me', 'in', 'front', 'of', 'the', 'commissioner', '.']
# ['<', 'eng', '>', 'i', 'know', 'whether', 'or', 'not', 'he', 'is', 'an', 'enemy', '.']
# ['<', 'eng', '>', 'i', 'should', "n't", 'have', 'to', 'put', 'up', 'with', 'this', 'noise', '.']
# ['<', 'eng', '>', 'pass', 'me', 'the', 'potatoes', '.']
# ['<', 'eng', '>', 'i', 'only', 'know', 'him', 'by', 'name', '.']
# ['<', 'eng', '>', 'i', 'try', 'not', 'to', 'think', 'about', 'it', '.']
# ['<', 'eng', '>', 'i', 'am', 'completely', 'against', 'it', '.']
# ['<', 'eng', '>', 'have', 'you', 'already', 'had', 'breakfast', '?']
# ['<', 'eng', '>', 'may', 'i', 'hang', 'up', 'your', 'coat', '?']
# ['<', 'eng', '>', 'the', 'police', 'found', 'evidence', 'that', 'the', 'man', 'committed', 'the', 'crime', '.']
# ['<', 'eng', '>', 'tom', 'intervened', 'in', 'his', 'coworkers', "'", 'disagreement', '.']
# ['<', 'eng', '>', 'i', 'really', 'do', "n't", 'want', 'to', 'go', 'to', 'boston', 'with', 'tom', '.']
# ['<', 'eng', '>', 'what', "'s", 'tom', 'so', 'unhappy', 'about', '?']
# ['<', 'eng', '>', 'i', 'admire', 'you', 'for', 'your', 'courage', '.']
# ['<', 'eng', '>', 'do', "n't", 'let', 'go', '.', 'hold', 'on', 'tight', '.']
# ['<', 'eng', '>', 'tom', 'told', 'mary', 'how', 'much', 'he', 'loved', 'her', '.']
# ['<', 'eng', '>', 'he', "'s", 'putting', 'on', 'a', 'coat', '.']
# ['<', 'eng', '>', 'do', "n't", 'carry', 'too', 'much', 'baggage', 'when', 'you', 'travel', '.']
# ['<', 'eng', '>', 'does', 'tom', 'have', 'to', 'write', 'the', 'letter', 'today', '?']
# ['<', 'eng', '>', 'you', "'d", 'better', 'believe', 'it', '.']
# ['<', 'eng', '>', 'she', 'used', 'to', 'wash', 'her', 'hair', 'before', 'going', 'to', 'school', '.']
# ['<', 'eng', '>', 'we', "'re", 'going', 'out', 'for', 'lunch', '.', 'do', 'you', 'want', 'to', 'come', ',', 'too', '?']
# ['<', 'eng', '>', 'i', 'can', 'make', 'it', 'in', 'two', 'hours', '.']
# ['<', 'eng', '>', 'i', "'ll", 'be', 'there', 'till', '2:30', '.']
# ['<', 'eng', '>', 'there', 'is', 'some', 'wind', '.']
# ['<', 'eng', '>', 'i', "'m", 'smarter', 'than', 'you', '.']
# ['<', 'eng', '>', 'i', 'know', 'i', 'should', "'ve", 'called', 'first', '.']
# ['<', 'eng', '>', 'tom', 'wants', 'to', 'get', 'in', 'touch', 'with', 'mary', '.']
# ['<', 'eng', '>', 'language', 'can', 'be', 'used', 'in', 'many', 'ways', '.']
# ['<', 'eng', '>', 'tom', 'was', "n't", 'paying', 'attention', '.']
# ['<', 'eng', '>', 'i', 'meant', 'no', 'harm', '.']
# ['<', 'eng', '>', 'though', 'she', 'was', 'tired', ',', 'she', 'kept', 'on', 'working', '.']
# ['<', 'eng', '>', 'tom', 'said', 'he', 'was', 'poor', '.']
# ['<', 'eng', '>', 'give', 'tom', 'my', 'regards', '.']
# ['<', 'eng', '>', 'do', 'you', 'play', 'any', 'sports', '?']
# ['<', 'eng', '>', 'take', 'off', 'your', 'socks', '.']
# ['<', 'eng', '>', 'everybody', 'danced', '.']
# ['<', 'eng', '>', 'thanks', 'for', 'coming', ',', 'tom', '.']
# ['<', 'eng', '>', 'i', 'guess', 'i', 'needed', 'someone', 'to', 'blame', '.']
# ['<', 'eng', '>', 'i', "'m", 'very', 'interested', 'in', 'classical', 'literature', '.']
# ['<', 'eng', '>', 'the', 'last', 'thing', 'i', 'want', 'to', 'do', 'is', 'give', 'you', 'any', 'reason', 'to', 'fire', 'me', '.']
# ['<', 'eng', '>', 'nobody', 'owns', 'the', 'moon', '.']
# ['<', 'eng', '>', 'those', 'are', 'good', '.']
# ['<', 'eng', '>', 'what', 'do', 'you', 'usually', 'have', 'for', 'breakfast', '?']
# ['<', 'eng', '>', 'tom', 'has', 'lost', 'his', 'focus', '.']
# ['<', 'eng', '>', 'the', 'little', 'girl', 'is', 'sucking', 'her', 'finger', '.']
# ['<', 'eng', '>', 'he', 'saw', 'he', 'was', 'wrong', '.']
# ['<', 'eng', '>', 'what', 'in', 'the', 'world', 'is', 'that', '?']
# ['<', 'eng', '>', 'they', "'re", 'eating', 'apples', '.']
# ['<', 'eng', '>', 'i', 'entered', 'the', 'restaurant', 'and', 'had', 'lunch', '.']
# ['<', 'eng', '>', 'do', 'you', 'know', 'how', 'to', 'cook', 'rice', 'well', '?']
# ['<', 'eng', '>', 'out', 'of', 'twenty', 'students', ',', 'only', 'one', 'has', 'read', 'the', 'book', '.']
# ['<', 'eng', '>', 'i', 'learned', 'from', 'my', 'mistakes', '.']
# ['<', 'eng', '>', 'at', 'what', 'age', 'do', 'you', 'want', 'to', 'get', 'married', '?']
# ['<', 'eng', '>', 'tom', 'is', 'careful', '.']
# ['<', 'eng', '>', 'do', "n't", 'forget', 'to', 'take', 'an', 'umbrella', 'in', 'case', 'it', 'rains', '.']
# ['<', 'eng', '>', 'he', 'likes', 'cooking', 'for', 'his', 'family', '.']
# ['<', 'eng', '>', 'these', 'plants', 'are', 'all', 'poisonous', '.']
# ['<', 'eng', '>', 'how', 'many', 'cars', 'does', 'the', 'tsubasa', 'have', '?']
# ['<', 'eng', '>', 'can', 'i', 'borrow', 'a', 'pen', '?', 'mine', "'s", 'on', 'its', 'last', 'legs', '.']
# ['<', 'eng', '>', 'can', 'i', 'bring', 'you', 'anything', 'else', '?']
# ['<', 'eng', '>', 'you', 'should', 'try', 'to', 'see', 'it', '.']
# ['<', 'eng', '>', 'i', 'think', 'we', 'should', 'call', 'tom', '.']
# ['<', 'eng', '>', 'what', 'time', 'do', 'you', 'usually', 'go', 'to', 'bed', '?']
# ['<', 'eng', '>', 'the', 'lake', 'is', 'deep', 'here', '.']
# ['<', 'eng', '>', 'that', "'s", 'my', 'dictionary', '.']
# ['<', 'eng', '>', 'what', 'are', 'they', 'saying', '?']
# ['<', 'eng', '>', 'my', 'father', 'made', 'me', 'a', 'delicious', 'lunch', '.']
# ['<', 'eng', '>', 'the', 'work', 'is', 'done', '.']
# ['<', 'eng', '>', 'what', "'s", 'the', 'best', 'way', 'to', 'chop', 'an', 'onion', '?']
# ['<', 'eng', '>', 'i', "'m", 'free', '.']
# ['<', 'eng', '>', 'christopher', 'columbus', 'discovered', 'america', '.']
# ['<', 'eng', '>', 'they', 'all', 'watched', '.']
# ['<', 'eng', '>', 'i', "'m", 'undressing', '.']
# ['<', 'eng', '>', 'what', 'he', 'says', 'is', 'very', 'important', '.']
# ['<', 'eng', '>', 'i', 'was', 'born', 'october', '10th', ',', '1972', '.']
# ['<', 'eng', '>', 'you', 'did', "n't", 'eat', 'much', 'lunch', '.']
# ['<', 'eng', '>', 'tom', 'was', 'told', 'he', 'had', 'cancer', 'just', 'recently', '.']
# ['<', 'eng', '>', 'i', "'m", 'sick', 'of', 'talking', 'about', 'it', '.']
# ['<', 'eng', '>', 'i', 'hurried', 'in', 'order', 'not', 'to', 'be', 'late', 'for', 'school', '.']
# ['<', 'eng', '>', 'it', "'s", 'bedtime', '.']
# ['<', 'eng', '>', 'get', 'that', 'book', 'for', 'me', '.']
# ['<', 'eng', '>', 'tom', 'is', 'still', 'your', 'best', 'friend', ',', 'is', "n't", 'he', '?']
# ['<', 'eng', '>', 'what', 'do', 'you', 'do', 'in', 'the', 'afternoon', '?']
# ['<', 'eng', '>', 'the', 'boy', 'started', 'crying', '.']
# ['<', 'eng', '>', 'i', 'spent', 'the', 'weekend', 'with', 'my', 'grandma', '.']
# ['<', 'eng', '>', 'this', 'is', 'such', 'a', 'sad', 'story', '.']
# ['<', 'eng', '>', 'i', 'will', 'send', 'it', 'by', 'email', 'this', 'afternoon', '.']
# ['<', 'eng', '>', 'there', 'is', 'a', 'big', 'hole', 'in', 'your', 'stocking', '.']
# ['<', 'eng', '>', 'i', "'d", 'like', 'a', 'little', 'bit', 'of', 'help', '.']
# ['<', 'eng', '>', 'tell', 'me', 'your', 'story', '.', 'i', 'am', 'all', 'ears', '.']
# ['<', 'eng', '>', 'they', 'launched', 'a', 'rocket', '.']
# ['<', 'eng', '>', 'nothing', 'seems', 'to', 'happen', 'around', 'here', '.']
# ['<', 'eng', '>', 'you', "'re", 'always', 'drunk', '.']
# ['<', 'eng', '>', 'they', "'re", 'very', 'dangerous', '.']
# ['<', 'eng', '>', 'butter', 'is', 'made', 'from', 'milk', '.']
# ['<', 'eng', '>', 'tom', 'is', 'quite', 'conceited', '.']
# ['<', 'eng', '>', 'i', 'need', 'a', 'new', 'one', '.']
# ['<', 'eng', '>', 'he', 'told', 'me', 'not', 'to', 'swim', 'there', '.']
# ['<', 'eng', '>', 'take', 'notes', '.']
# ['<', 'eng', '>', 'guess', 'what', 'happened', 'to', 'me', '.']
# ['<', 'eng', '>', 'i', 'love', 'tapioca', 'pudding', '.']
# ['<', 'eng', '>', 'why', 'do', 'you', 'love', 'me', '?']
# ['<', 'eng', '>', 'half', 'of', 'the', 'apples', 'are', 'rotten', '.']
# ['<', 'eng', '>', 'she', 'married', 'him', 'when', 'she', 'was', '20', '.']
# ['<', 'eng', '>', 'the', 'president', 'seemed', 'strong', '.']
# ['<', 'eng', '>', 'she', 'advised', 'him', 'to', 'use', 'a', 'bicycle', '.']
# ['<', 'eng', '>', 'i', "'m", 'looking', 'for', 'a', 'place', 'to', 'sleep', '.']
# ['<', 'eng', '>', 'tom', 'is', 'from', 'boston', ',', 'but', 'now', 'he', 'lives', 'in', 'chicago', '.']
# ['<', 'eng', '>', 'you', 'must', 'stay', 'with', 'me', '.']
# ['<', 'eng', '>', 'there', "'s", 'more', 'wind', 'today', 'than', 'yesterday', '.']
# ['<', 'eng', '>', 'i', 'hate', 'to', 'iron', '.']
# ['<', 'eng', '>', 'i', 'remember', 'what', 'he', 'said', '.']
# ['<', 'eng', '>', 'someone', 'has', 'taken', 'my', 'shoes', 'by', 'mistake', '.']
# ['<', 'eng', '>', 'it', 'is', 'uncertain', 'whether', 'he', 'is', 'coming', 'or', 'not', '.']
# ['<', 'eng', '>', 'they', 'could', "n't", 'stop', 'laughing', '.']
# ['<', 'eng', '>', 'it', "'s", 'too', 'heavy', '.']
# ['<', 'eng', '>', 'our', 'health', 'is', 'our', 'most', 'precious', 'possession', '.']
# ['<', 'eng', '>', 'tom', 'has', 'never', 'seen', 'a', 'giraffe', '.']
# ['<', 'eng', '>', 'she', 'invited', 'him', 'in', '.']
# ['<', 'eng', '>', 'the', 'rainy', 'weather', 'lasted', 'for', 'ten', 'days', 'straight', '.']
# ['<', 'eng', '>', 'i', 'can', 'not', 'afford', 'to', 'buy', 'a', 'used', 'car', '.']
# ['<', 'eng', '>', 'you', "'re", 'not', 'doing', 'your', 'share', '.']
# ['<', 'eng', '>', 'would', 'you', 'like', 'to', 'freshen', 'up', '?']
# ['<', 'eng', '>', 'do', 'you', 'know', 'how', 'many', 'people', 'died', 'in', 'yesterday', "'s", 'plane', 'crash', '?']
# ['<', 'eng', '>', 'he', "'s", 'just', 'an', 'ordinary', 'student', '.']
# ['<', 'eng', '>', 'tom', 'should', 'be', 'at', 'home', '.']
# ['<', 'eng', '>', 'he', 'dozed', 'off', '.']
# ['<', 'eng', '>', 'i', "'m", 'very', 'busy', 'today', '.']
# ['<', 'eng', '>', 'is', 'that', 'you', '?']
# ['<', 'eng', '>', 'that', "'s", 'his', 'house', '.']
# ['<', 'eng', '>', 'my', 'mother', 'was', 'very', 'pretty', 'when', 'she', 'was', 'young', '.']
# ['<', 'eng', '>', 'i', "'m", 'not', 'going', 'anyway', '.']
# ['<', 'eng', '>', 'deer', 'are', 'fairly', 'intelligent', '.']
# ['<', 'eng', '>', 'give', 'me', 'a', 'little', 'more', 'time', '.']
# ['<', 'eng', '>', 'you', 'have', 'beautiful', 'eyes', '.']
# ['<', 'eng', '>', 'i', 'would', 'like', 'to', 'book', 'a', 'flight', 'to', 'brazil', '.']
# ['<', 'eng', '>', 'he', 'chose', 'to', 'live', 'in', 'tokyo', 'instead', 'of', 'osaka', '.']
# ['<', 'eng', '>', 'god', 'knows', 'that', 'it', 'is', 'true', '.']
# ['<', 'eng', '>', 'i', 'will', 'help', 'you', 'if', 'possible', '.']
# ['<', 'eng', '>', 'tom', 'ca', "n't", 'run', 'as', 'fast', 'as', 'mary', '.']
# ['<', 'eng', '>', 'tom', 'heard', 'the', 'sound', 'of', 'rain', 'on', 'the', 'tin', 'roof', '.']
# ['<', 'eng', '>', 'he', 'does', "n't", 'remember', 'me', 'anymore', '.']
# ['<', 'eng', '>', 'now', 'i', 'get', 'it', '.']
# ['<', 'eng', '>', 'everyone', 'wants', 'me', 'to', 'go', ',', 'but', 'i', 'do', "n't", 'feel', 'like', 'going', '.']
# ['<', 'eng', '>', 'his', 'father', 'passed', 'away', 'last', 'year', '.']
# ['<', 'eng', '>', 'children', 'often', 'ask', 'me', 'for', 'money', '.']
# ['<', 'eng', '>', 'this', 'is', 'a', 'car', 'imported', 'from', 'germany', '.']
# ['<', 'eng', '>', 'i', "'m", 'not', 'working', 'for', 'tom', '.']
# ['<', 'eng', '>', 'our', 'teacher', 'is', 'a', 'real', 'idiot', '.']
# ['<', 'eng', '>', 'both', 'of', 'my', 'parents', 'are', 'dead', '.']
# ['<', 'eng', '>', 'tom', 'could', "n't", 'eat', 'the', 'whole', 'sandwich', '.']
# ['<', 'eng', '>', 'no', 'one', 'warned', 'me', '.']
# ['<', 'eng', '>', 'i', 'consider', 'making', 'mistakes', 'an', 'important', 'part', 'of', 'the', 'learning', 'process', '.']
# ['<', 'eng', '>', 'i', "'ll", 'walk', '.']
# ['<', 'eng', '>', 'he', 'is', 'above', 'suspicion', '.']
# ['<', 'eng', '>', 'cockfighting', 'is', 'banned', 'in', 'many', 'countries', '.']
# ['<', 'eng', '>', 'she', 'made', 'cookies', 'for', 'the', 'children', '.']
# ['<', 'eng', '>', 'when', 'was', 'the', 'last', 'time', 'you', 'painted', 'your', 'house', '?']
# ['<', 'eng', '>', 'we', "'re", 'sorry', '.']
# ['<', 'eng', '>', 'i', 'love', 'my', 'friends', '.']
# ['<', 'eng', '>', 'do', "n't", 'worry', '.', 'it', "'s", 'ok', '.']
# ['<', 'eng', '>', 'he', 'poured', 'cold', 'water', 'over', 'himself', '.']
# ['<', 'eng', '>', 'that', 'is', 'different', 'than', 'what', 'i', 'had', 'expected', '.']
# ['<', 'eng', '>', 'hey', ',', 'come', 'here', '.']
# ['<', 'eng', '>', 'turn', 'off', 'the', 'radio', ',', 'please', '.']
# ['<', 'eng', '>', 'do', "n't", 'call', 'me', 'a', 'jerk', '.']
# ['<', 'eng', '>', 'the', 'grass', 'is', 'always', 'greener', 'on', 'the', 'other', 'side', '.']
# ['<', 'eng', '>', 'she', 'advised', 'him', 'to', 'do', 'more', 'exercise', '.']
# ['<', 'eng', '>', 'he', 'has', 'more', 'books', 'than', 'he', 'can', 'read', '.']
# ['<', 'eng', '>', 'they', "'re", 'insane', '.']
# ['<', 'eng', '>', 'tom', 'did', 'a', 'good', 'job', 'organizing', 'the', 'workers', '.']
# ['<', 'eng', '>', 'he', 'wo', "n't", 'come', ',', 'will', 'he', '?']
# ['<', 'eng', '>', 'keep', 'your', 'eyes', 'on', 'the', 'road', '.']
# ['<', 'eng', '>', 'do', 'you', 'have', 'time', 'on', 'tuesday', '?']
# ['<', 'eng', '>', 'she', 'advised', 'him', 'to', 'go', 'to', 'the', 'hospital', '.']
# ['<', 'eng', '>', 'i', 'have', 'a', 'special', 'relationship', 'with', 'my', 'aunt', '.']
# ['<', 'eng', '>', 'catch', 'him', '.']
# ['<', 'eng', '>', 'who', 'told', 'you', 'i', 'was', 'canadian', '?']
# ['<', 'eng', '>', 'it', "'s", 'not', 'a', 'game', '.']
# ['<', 'eng', '>', 'tom', 'always', 'complains', 'about', 'what', 'mary', 'does', '.']
# ['<', 'eng', '>', 'you', 'deserve', 'a', 'medal', '.']
# ['<', 'eng', '>', 'incentives', 'always', 'help', '.']
# ['<', 'eng', '>', 'what', 'kind', 'of', 'food', 'do', 'you', 'like', 'to', 'eat', '?']
# ['<', 'eng', '>', 'the', 'sky', 'is', 'cloudy', 'today', '.']
# ['<', 'eng', '>', 'maybe', 'it', 'was', "n't", 'tom', '.']
# ['<', 'eng', '>', 'stop', 'whining', 'like', 'a', 'baby', '.']
# ['<', 'eng', '>', 'do', 'you', 'want', 'to', 'sit', 'down', '?']
# ['<', 'eng', '>', 'she', "'s", 'in', 'the', 'garden', 'planting', 'roses', '.']
# ['<', 'eng', '>', 'tom', 'could', "n't", 'understand', 'a', 'single', 'word', 'of', 'what', 'mary', 'said', '.']
# ['<', 'eng', '>', 'i', 'do', "n't", 'know', 'how', 'to', 'thank', 'you', '.']
# ['<', 'eng', '>', 'tom', 'is', 'a', 'liar', 'if', 'he', 'says', 'he', 'saw', 'us', 'together', '.']
# ['<', 'eng', '>', 'why', 'wo', "n't", 'tom', 'listen', 'to', 'me', '?']
# ['<', 'eng', '>', 'as', 'far', 'as', 'politics', 'is', 'concerned', ',', 'he', "'s", 'still', 'as', 'innocent', 'as', 'a', 'child', '.']
# ['<', 'eng', '>', 'i', 'know', 'what', "'s", 'wrong', 'with', 'you', '.']
# ['<', 'eng', '>', 'i', 'invited', 'twelve', 'people', 'to', 'my', 'party', ',', 'but', 'one', 'of', 'them', 'could', "n't", 'come', '.']
# ['<', 'eng', '>', 'leave', 'a', 'message', '.']
# ['<', 'eng', '>', 'are', 'you', 'still', 'around', '?']
# ['<', 'eng', '>', 'i', 'should', 'go', 'to', 'boston', '.']
# ['<', 'eng', '>', 'as', 'soon', 'as', 'they', 'return', ',', 'i', 'will', 'telephone', 'you', '.']
# ['<', 'eng', '>', 'this', 'is', "n't", 'what', 'i', 'asked', 'for', '.']
# ['<', 'eng', '>', 'the', 'sickness', 'is', 'taking', 'its', 'course', '.']
# ['<', 'eng', '>', 'she', 'is', 'very', 'sensitive', 'to', 'criticism', '.']
# ['<', 'eng', '>', 'we', "'re", 'not', 'the', 'only', 'ones', 'here', 'who', 'know', 'tom', '.']
# ['<', 'eng', '>', 'please', 'send', 'me', 'your', 'latest', 'catalogue', '.']
# ['<', 'eng', '>', 'we', 'showed', 'him', 'some', 'pictures', 'of', 'london', '.']
# ['<', 'eng', '>', 'you', 'had', 'better', 'go', '.']
# ['<', 'eng', '>', 'let', 'go', 'of', 'me', '!']
# ['<', 'eng', '>', 'are', "n't", 'you', 'hungry', '?']
# ['<', 'eng', '>', 'tom', 'left', 'several', 'messages', 'on', 'my', 'phone', '.']
# ['<', 'eng', '>', 'where', 'should', 'we', 'meet', '?']
# ['<', 'eng', '>', 'give', 'him', 'an', 'inch', 'and', 'he', "'ll", 'take', 'a', 'yard', '.']
# ['<', 'eng', '>', 'it', 'is', 'certainly', 'possible', 'if', 'you', 'want', 'it', '.']
# ['<', 'eng', '>', 'he', "'ll", 'run', 'out', 'of', 'luck', 'sooner', 'or', 'later', '.']
# ['<', 'eng', '>', 'tom', 'clicked', 'his', 'fingers', '.']
# ['<', 'eng', '>', 'she', "'s", 'pregnant', 'with', 'twins', '.']
# ['<', 'eng', '>', 'you', 'were', 'having', 'fun', ',', 'were', "n't", 'you', '?']
# ['<', 'eng', '>', 'i', 'always', 'get', 'up', 'at', '6', "o'clock", 'in', 'the', 'morning', '.']
# ['<', 'eng', '>', 'she', 'sat', 'next', 'him', 'with', 'her', 'eyes', 'closed', '.']
# ['<', 'eng', '>', 'she', 'wants', 'to', 'marry', 'her', 'daughter', 'to', 'a', 'doctor', '.']
# ['<', 'eng', '>', 'i', 'do', "n't", 'know', 'whether', 'tom', 'will', 'swim', 'or', 'not', '.']
# ['<', 'eng', '>', 'milk', 'is', 'a', 'popular', 'beverage', '.']
# ['<', 'eng', '>', 'what', 'day', 'is', 'it', 'today', '?']
# ['<', 'eng', '>', 'this', 'watch', 'is', 'expensive', '.']
# ['<', 'eng', '>', 'she', 'spends', 'as', 'much', 'money', 'as', 'she', 'earns', '.']
# ['<', 'eng', '>', 'that', "'s", 'probably', 'a', 'good', 'idea', '.']
# ['<', 'eng', '>', 'tom', 'was', 'executed', '.']
# ['<', 'eng', '>', 'i', 'do', "n't", 'understand', 'this', 'part', '.']
# ['<', 'eng', '>', 'what', 'will', 'you', 'wear', '?']
# ['<', 'eng', '>', 'i', 'told', 'her', 'to', 'sit', 'down', 'and', 'drink', 'a', 'glass', 'of', 'water', '.']
# ['<', 'eng', '>', 'tom', 'likes', 'taking', 'walks', 'with', 'mary', '.']
# ['<', 'eng', '>', 'there', "'s", 'a', 'small', 'brown', 'dog', 'under', 'this', 'table', '.']
# ['<', 'eng', '>', 'i', 'would', 'like', 'to', 'buy', 'this', 'watch', ',', 'but', 'unfortunately', 'it', "'s", 'just', 'too', 'expensive', '.']
# ['<', 'eng', '>', 'my', 'mother', 'is', 'a', 'high', 'school', 'teacher', '.']
# ['<', 'eng', '>', 'i', 'always', 'have', 'trouble', 'remembering', 'names', '.']
# ['<', 'eng', '>', 'it', "'s", 'a', 'little', 'cold', 'today', '.']
# ['<', 'eng', '>', 'do', "n't", 'swim', 'in', 'the', 'river', '.']
# ['<', 'eng', '>', 'tom', 'and', 'his', 'friends', 'went', 'to', 'the', 'circus', '.']
# ['<', 'eng', '>', 'what', 'does', 'your', 'job', 'entail', '?']
# ['<', 'eng', '>', 'i', "'d", 'like', 'to', 'know', 'how', 'tom', 'got', 'there', '.']
# ['<', 'eng', '>', 'the', 'old', 'shack', 'seems', 'to', 'have', 'weathered', 'the', 'storm', 'pretty', 'well', '.']
# ['<', 'eng', '>', 'i', 'had', 'never', 'been', 'abroad', 'before', ',', 'so', 'everything', 'seemed', 'strange', 'to', 'me', '.']
# ['<', 'eng', '>', 'why', 'does', "n't", 'anybody', 'help', 'tom', '?']
# ['<', 'eng', '>', 'tom', 'has', 'a', 'high', 'threshold', 'for', 'pain', '.']
# ['<', 'eng', '>', 'there', 'is', 'a', 'little', 'hope', 'that', 'he', 'will', 'succeed', '.']
# ['<', 'eng', '>', 'do', 'you', 'know', 'each', 'other', '?']
# ['<', 'eng', '>', 'i', 'want', 'to', 'show', 'you', 'something', ',', 'tom', '.']
# ['<', 'eng', '>', 'how', 'many', 'ways', 'are', 'there', 'to', 'do', 'that', '?']
# ['<', 'eng', '>', 'do', "n't", 'despise', 'others', 'because', 'they', 'are', 'poor', '.']
# ['<', 'eng', '>', 'the', 'sun', 'is', 'setting', '.']
# ['<', 'eng', '>', 'they', 'walked', 'around', '.']
# ['<', 'eng', '>', 'thanks', 'in', 'advance', '.']
# ['<', 'eng', '>', 'in', 'other', 'words', ',', 'i', 'do', "n't", 'like', 'to', 'work', 'with', 'him', '.']
# ['<', 'eng', '>', 'i', "'ll", 'have', 'to', 'think', 'about', 'it', '.']
# ['<', 'eng', '>', 'since', 'i', 'was', 'thirsty', ',', 'i', 'drank', 'water', '.']
# ['<', 'eng', '>', 'i', "'m", 'too', 'poor', 'to', 'buy', 'a', 'new', 'suit', '.']
# ['<', 'eng', '>', 'tom', 'could', 'be', 'canadian', '.']
# ['<', 'eng', '>', 'tom', 'was', 'not', 'much', 'older', 'than', 'mary', '.']
# ['<', 'eng', '>', 'why', 'did', 'you', 'say', 'that', '?']
# ['<', 'eng', '>', 'i', 'did', "n't", 'want', 'to', 'tell', 'you', 'that', 'on', 'the', 'phone', '.']
# ['<', 'eng', '>', 'share', 'your', 'experience', '.']
# ['<', 'eng', '>', 'i', "'m", 'going', 'to', 'clean', 'your', 'bedroom', 'today', '.']
# ['<', 'eng', '>', 'what', 'time', 'is', 'it', ',', 'anyway', '?']
# ['<', 'eng', '>', 'what', "'s", 'your', 'favorite', 'book', '?']
# ['<', 'eng', '>', 'tom', 'came', 'on', 'monday', 'and', 'went', 'back', 'home', 'the', 'next', 'day', '.']
# ['<', 'eng', '>', 'my', 'kids', 'have', 'their', 'spring', 'break', 'soon', '.']
# ['<', 'eng', '>', 'i', 'know', 'this', 'does', "n't", 'make', 'much', 'sense', '.']
# ['<', 'eng', '>', 'i', 'do', "n't", 'think', 'that', 'changes', 'anything', '.']
# ['<', 'eng', '>', 'i', 'wish', 'there', 'were', 'more', 'people', 'like', 'you', '.']
# ['<', 'eng', '>', 'tom', 'lost', 'his', 'dog', '.']
# ['<', 'eng', '>', 'i', 'want', 'you', 'to', 'stop', 'looking', 'for', 'tom', '.']
# ['<', 'eng', '>', 'butter', 'is', 'made', 'from', 'cream', '.']
# ['<', 'eng', '>', 'tom', 'usually', 'takes', 'a', 'shower', 'before', 'eating', 'breakfast', '.']
# ['<', 'eng', '>', 'tom', 'sat', 'beside', 'mary', '.']
# ['<', 'eng', '>', 'i', 'want', 'you', 'to', 'follow', 'tom', '.']
# ['<', 'eng', '>', 'the', 'blood', 'was', 'bright', 'red', '.']
# ['<', 'eng', '>', 'tom', 'drinks', 'coffee', '.']
# ['<', 'eng', '>', 'tom', 'also', 'speaks', 'french', '.']
# ['<', 'eng', '>', 'he', 'felt', 'very', 'lonely', '.']
# ['<', 'eng', '>', 'you', 'are', 'good', '.']
# ['<', 'eng', '>', 'he', 'is', 'good', 'at', 'singing', '.']
# ['<', 'eng', '>', 'i', 'let', 'go', 'of', 'the', 'rope', '.']
# ['<', 'eng', '>', 'the', 'house', 'is', 'cold', '.']
# ['<', 'eng', '>', 'stand', 'in', 'line', '.']
# ['<', 'eng', '>', 'that', "'s", 'an', 'excellent', 'choice', '.']
# ['<', 'eng', '>', 'these', 'tomatoes', 'do', "n't", 'have', 'any', 'taste', '.']
# ['<', 'eng', '>', 'i', 'have', "n't", 'seen', 'you', 'since', 'high', 'school', '.']
# ['<', 'eng', '>', 'i', 'stay', 'home', 'alone', 'while', 'my', 'parents', 'are', 'at', 'work', '.']
# ['<', 'eng', '>', 'you', "'re", 'amusing', '.']
# ['<', 'eng', '>', 'this', 'coffee', 'is', 'too', 'strong', 'for', 'me', '.']
# ['<', 'eng', '>', 'my', 'alarm', 'clock', 'did', "n't", 'go', 'off', 'this', 'morning', ',', 'so', 'i', 'was', 'late', 'for', 'school', '.']
# ['<', 'eng', '>', 'i', 'had', 'no', 'choice', 'but', 'to', 'take', 'the', 'plane', '.']
# ['<', 'eng', '>', 'he', 'never', 'puts', 'off', 'anything', 'he', 'has', 'to', 'do', '.']
# ['<', 'eng', '>', 'tom', 'just', 'does', "n't", 'know', 'what', 'to', 'do', '.']
# ['<', 'eng', '>', 'are', 'you', 'going', 'to', 'learn', 'english', '?']
# ['<', 'eng', '>', 'what', "'s", 'your', 'favorite', 'outfit', '?']
# ['<', 'eng', '>', 'the', 'flowers', 'withered', 'up', '.']
# ['<', 'eng', '>', 'he', 'has', 'a', 'good', 'command', 'of', 'french', '.']
# ['<', 'eng', '>', 'tom', 'showers', 'every', 'morning', '.']
# ['<', 'eng', '>', 'when', 'they', 'saw', 'that', 'they', 'were', 'losing', ',', 'they', 'gave', 'up', '.']
# ['<', 'eng', '>', 'tom', 'has', 'nothing', 'better', 'to', 'do', '.']
# ['<', 'eng', '>', 'everybody', 'likes', 'you', '.']
# ['<', 'eng', '>', 'we', 'came', 'to', 'apologize', '.']
# ['<', 'eng', '>', 'i', 'think', 'it', "'s", 'unlikely', 'that', 'plants', 'feel', 'pain', '.']
# ['<', 'eng', '>', 'the', 'crew', 'abandoned', 'the', 'ship', '.']
# ['<', 'eng', '>', 'this', 'is', 'remarkable', '.']
# ['<', 'eng', '>', 'is', 'that', 'too', 'much', 'to', 'ask', '?']
# ['<', 'eng', '>', 'he', 'sat', 'on', 'the', 'bed', '.']
# ['<', 'eng', '>', 'my', 'idea', 'is', 'better', ',', 'i', 'think', '.']
# ['<', 'eng', '>', 'i', 'have', 'a', 'cat', 'and', 'a', 'dog', '.', 'the', 'cat', "'s", 'black', 'and', 'the', 'dog', "'s", 'white', '.']
# ['<', 'eng', '>', 'he', 'talks', 'as', 'if', 'he', 'knew', 'everything', '.']
# ['<', 'eng', '>', 'do', 'you', 'like', 'this', 'design', '?']
# ['<', 'eng', '>', 'i', 'bought', 'you', 'a', 'kite', '.']
# ['<', 'eng', '>', 'you', 'have', 'until', 'midnight', '.']
# ['<', 'eng', '>', 'tom', 'had', 'a', 'fight', 'with', 'mary', '.']
# ['<', 'eng', '>', 'he', 'was', 'given', 'up', 'for', 'dead', '.']
# ['<', 'eng', '>', 'june', 'is', 'the', 'month', 'when', 'we', 'have', 'a', 'lot', 'of', 'rain', '.']
# ['<', 'eng', '>', 'i', 'do', "n't", 'know', 'who', 'did', 'this', '.']
# ['<', 'eng', '>', 'i', 'should', 'study', 'french', '.']
# ['<', 'eng', '>', 'with', 'the', 'coming', 'of', 'spring', ',', 'everything', 'is', 'gradually', 'coming', 'to', 'life', 'again', '.']
# ['<', 'eng', '>', 'i', 'need', 'a', 'good', 'lawyer', '.']
# ['<', 'eng', '>', 'i', 'helped', 'them', 'yesterday', '.']
# ['<', 'eng', '>', 'i', "'m", 'sorry', 'to', 'have', 'caused', 'you', 'so', 'much', 'trouble', '.']
# ['<', 'eng', '>', 'we', 'have', 'to', 'think', 'over', 'the', 'plan', '.']
# ['<', 'eng', '>', 'he', 'does', "n't", 'know', 'a', 'lot', 'about', 'japan', '.']
# ['<', 'eng', '>', 'they', "'re", 'fine', '.']
# ['<', 'eng', '>', 'they', 'are', 'leaving', 'in', 'three', 'days', ',', 'that', 'is', 'to', 'say', 'june', '10th', '.']
# ['<', 'eng', '>', 'tom', "'s", 'son', "'s", 'name', 'is', 'john', '.']
# ['<', 'eng', '>', 'i', "'m", 'too', 'old', 'for', 'her', '.']
# ['<', 'eng', '>', 'why', 'does', "n't", 'tom', 'like', 'boston', '?']
# ['<', 'eng', '>', 'they', 'are', 'our', 'cars', '.']
# ['<', 'eng', '>', 'i', 'regret', 'saying', 'that', 'you', 'were', 'wrong', '.']
# ['<', 'eng', '>', 'i', 'did', 'it', 'on', 'my', 'own', '.']
# ['<', 'eng', '>', 'do', 'you', 'want', 'to', 'watch', 'the', 'baseball', 'game', 'on', 'tv', '?']
# ['<', 'eng', '>', 'call', 'the', 'hospital', '.']
# ['<', 'eng', '>', 'i', 'do', "n't", 'even', 'know', 'your', 'address', '.']
# ['<', 'eng', '>', 'is', 'eating', 'too', 'much', 'fiber', 'bad', 'for', 'you', '?']
# ['<', 'eng', '>', 'i', 'remember', 'those', 'times', '.']
# ['<', 'eng', '>', 'i', 'have', 'to', 'tell', 'tom', 'something', '.']
# ['<', 'eng', '>', 'tom', 'claimed', 'that', 'he', 'saw', 'a', 'man', 'being', 'eaten', 'alive', 'by', 'piranhas', '.']
# ['<', 'eng', '>', 'i', 'ca', "n't", 'tell', 'you', 'how', 'to', 'do', 'that', '.']
# ['<', 'eng', '>', 'tom', 'will', 'love', 'it', '.']
# ['<', 'eng', '>', 'tom', 'is', 'taking', 'pictures', '.']
# ['<', 'eng', '>', 'wait', 'for', 'tom', '.']
# ['<', 'eng', '>', 'tom', 'is', 'from', 'australia', '.']
# ['<', 'eng', '>', 'tom', 'wondered', 'what', 'happened', 'to', 'mary', '.']
# ['<', 'eng', '>', 'her', 'face', 'turned', 'white', '.']
# ['<', 'eng', '>', 'the', 'room', 'was', 'quiet', '.']
# ['<', 'eng', '>', 'we', 'volunteered', '.']
# ['<', 'eng', '>', 'the', 'whole', 'family', 'was', 'sick', 'in', 'bed', '.']
# ['<', 'eng', '>', 'the', 'story', 'takes', 'place', 'in', 'lisbon', '.']
# ['<', 'eng', '>', 'she', 'lives', 'a', 'few', 'blocks', 'away', 'from', 'here', '.']
# ['<', 'eng', '>', 'being', '25', 'letters', 'long', ',', "'anticonstitutionnellement", "'", 'is', 'the', 'longest', 'word', 'in', 'french', '.']
# ['<', 'eng', '>', 'tom', 'handed', 'mary', 'a', 'check', 'for', 'half', 'a', 'million', 'dollars', '.']
# ['<', 'eng', '>', 'the', 'more', 'you', 'explain', 'it', ',', 'the', 'more', 'i', 'do', "n't", 'understand', 'it', '.']
# ['<', 'eng', '>', 'control', 'yourself', '.']
# ['<', 'eng', '>', 'he', 'does', "n't", 'live', 'there', 'anymore', '.']
# ['<', 'eng', '>', 'i', 'could', 'not', 'keep', 'the', 'tears', 'from', 'my', 'eyes', '.']
# ['<', 'eng', '>', 'it', 'is', 'nice', 'to', 'be', 'among', 'family', '.']
# ['<', 'eng', '>', 'i', 'want', 'tom', 'to', 'understand', 'what', 'has', 'to', 'be', 'done', '.']
# ['<', 'eng', '>', 'tom', 'lost', 'more', 'than', 'a', 'hundred', 'pounds', '.']
# ['<', 'eng', '>', 'after', 'she', 'had', 'read', 'the', 'letter', ',', 'she', 'tore', 'it', 'to', 'pieces', '.']
# ['<', 'eng', '>', 'my', 'friends', 'went', 'to', 'the', 'movies', 'without', 'me', '.']
# ['<', 'eng', '>', 'is', "n't", 'it', 'about', 'time', 'you', 'guys', 'buried', 'the', 'hatchet', 'and', 'let', 'bygones', 'be', 'bygones', '?']
# ['<', 'eng', '>', 'i', 'do', "n't", 'feel', 'like', 'translating', 'this', 'sentence', '.']
# ['<', 'eng', '>', 'which', 'platform', 'is', 'the', 'train', 'for', 'boston', '?']
# ['<', 'eng', '>', 'whose', 'newspaper', 'is', 'this', '?']
# ['<', 'eng', '>', 'you', 'neglected', 'to', 'say', '``', 'thank', 'you', '.', "''"]
# ['<', 'eng', '>', 'it', "'s", 'considered', 'to', 'be', 'an', 'important', 'matter', '.']
# ['<', 'eng', '>', 'we', 'make', 'butter', 'from', 'milk', '.']
# ['<', 'eng', '>', 'he', 'does', "n't", 'have', 'a', 'hat', 'on', '.']
# ['<', 'eng', '>', 'why', 'do', 'you', 'take', 'so', 'long', 'to', 'eat', '?']
# ['<', 'eng', '>', 'why', 'do', "n't", 'you', 'go', 'on', 'a', 'diet', '?']
# ['<', 'eng', '>', 'do', 'you', 'like', 'this', 'book', '?']
# ['<', 'eng', '>', 'will', 'you', 'dance', 'with', 'me', '?']
# ['<', 'eng', '>', 'the', 'school', 'year', 'begins', 'on', 'the', '10th', 'of', 'april', '.']
# ['<', 'eng', '>', 'i', 'only', 'saw', 'him', 'once', '.']
# ['<', 'eng', '>', 'she', 'took', 'the', 'book', 'back', 'to', 'the', 'library', '.']
# ['<', 'eng', '>', 'going', 'to', 'this', 'school', 'requires', 'a', 'lot', 'of', 'money', '.']
# ['<', 'eng', '>', 'do', "n't", 'break', 'up', 'with', 'me', '.']
# ['<', 'eng', '>', 'i', 'have', "n't", 'been', 'able', 'to', 'solve', 'the', 'problem', 'yet', '.']
# ['<', 'eng', '>', 'i', "'ve", 'found', 'the', 'key', '.']
# ['<', 'eng', '>', 'when', 'i', 'saw', 'his', 'mother', 'yesterday', ',', 'she', 'said', 'he', 'had', 'left', 'the', 'hospital', 'a', 'week', 'before', '.']
# ['<', 'eng', '>', 'how', 'much', 'longer', 'will', 'it', 'take', 'for', 'the', 'tub', 'to', 'fill', '?']
# ['<', 'eng', '>', 'mary', 'is', 'so', 'pretty', '.']
# ['<', 'eng', '>', 'can', 'i', 'catch', 'a', 'taxi', 'near', 'here', '?']
# ['<', 'eng', '>', 'do', "n't", 'go', 'out', 'after', 'it', 'gets', 'dark', '.']
# ['<', 'eng', '>', 'you', 'ought', 'not', 'to', 'say', 'such', 'a', 'thing', '.']
# ['<', 'eng', '>', 'it', 'looks', 'easy', 'when', 'you', 'do', 'it', '.']
# ['<', 'eng', '>', 'the', 'gardener', 'did', "n't", 'let', 'us', 'walk', 'on', 'the', 'grass', '.']
# ['<', 'eng', '>', 'please', 'turn', 'over', '.']
# ['<', 'eng', '>', 'he', 'was', 'robbed', 'of', 'all', 'his', 'money', '.']
# ['<', 'eng', '>', 'tom', 'and', 'mary', 'said', 'that', 'they', 'were', 'leaving', '.']
# ['<', 'eng', '>', 'let', 'me', 'thread', 'the', 'needle', 'for', 'you', '.']
# ['<', 'eng', '>', 'phoenix', 'is', 'the', 'capital', 'of', 'arizona', '.']
# ['<', 'eng', '>', 'he', 'is', 'too', 'drunk', 'to', 'drive', 'home', '.']
# ['<', 'eng', '>', 'the', 'little', 'girl', 'did', 'nothing', 'but', 'cry', '.']
# ['<', 'eng', '>', 'tom', 'is', "n't", 'strict', 'enough', 'with', 'his', 'students', '.']
# ['<', 'eng', '>', 'tom', 'should', "n't", 'have', 'told', 'mary', 'about', 'john', '.']
# ['<', 'eng', '>', 'blackboards', 'are', 'not', 'always', 'black', '.']
# ['<', 'eng', '>', 'when', 'the', 'boys', 'go', 'camping', ',', 'they', 'enjoy', 'living', 'in', 'a', 'primitive', 'way', '.']
# ['<', 'eng', '>', 'i', "'m", 'halfway', 'through', 'this', 'crime', 'novel', '.']
# ['<', 'eng', '>', 'whatever', 'happens', ',', 'i', "'ll", 'stick', 'to', 'my', 'principles', 'to', 'the', 'bitter', 'end', '.']
# ['<', 'eng', '>', 'i', 'hated', 'tom', '.']
# ['<', 'eng', '>', 'it', "'s", 'a', 'matter', 'of', 'time', '.']
# ['<', 'eng', '>', 'he', 'is', 'an', 'expert', 'at', 'fishing', '.']
# ['<', 'eng', '>', 'i', "'ve", 'heard', 'of', 'you', '.']
# ['<', 'eng', '>', 'is', 'there', 'no', 'other', 'way', '?']
# ['<', 'eng', '>', 'i', 'aimed', 'my', 'gun', 'at', 'the', 'target', '.']
# ['<', 'eng', '>', 'our', 'world', 'is', 'getting', 'smaller', 'and', 'smaller', '.']
# ['<', 'eng', '>', 'he', 'told', 'everyone', '.']
# ['<', 'eng', '>', 'i', 'can', 'do', 'this', 'all', 'day', '.']
# ['<', 'eng', '>', 'he', 'did', "n't", 'say', 'a', 'word', '.']
# ['<', 'eng', '>', 'this', 'is', 'very', 'interesting', '.']
# ['<', 'eng', '>', 'you', 'can', 'spend', 'the', 'night', 'with', 'us', '.']
# ['<', 'eng', '>', 'you', 'can', 'say', 'what', 'you', 'like', ',', 'but', 'i', "'ll", 'never', 'forgive', 'you', '.']
# ['<', 'eng', '>', 'i', 'wish', 'you', 'were', 'close', 'to', 'me', '.']
# ['<', 'eng', '>', 'to', 'make', 'matters', 'worse', ',', 'he', 'fell', 'ill', '.']
# ['<', 'eng', '>', 'tom', 'was', 'quite', 'handsome', 'when', 'he', 'was', 'young', '.']
# ['<', 'eng', '>', 'tom', 'died', 'monday', 'afternoon', '.']
# ['<', 'eng', '>', 'those', 'children', 'are', 'waiting', 'for', 'their', 'mother', '.']
# ['<', 'eng', '>', 'she', "'s", 'very', 'beautiful', '.']
# ['<', 'eng', '>', 'if', 'you', 'go', 'out', 'so', 'lightly', 'dressed', ',', 'you', "'ll", 'catch', 'a', 'cold', '.']
# ['<', 'eng', '>', 'have', 'you', 'been', 'told', 'about', 'the', 'problem', '?']
# ['<', 'eng', '>', 'i', 'want', 'to', 'study', 'abroad', 'next', 'year', '.']
# ['<', 'eng', '>', 'tom', 'assured', 'mary', 'that', 'he', "'d", 'help', 'her', 'paint', 'the', 'ceiling', 'of', 'her', 'kitchen', '.']
# ['<', 'eng', '>', 'he', 'is', 'dreaming', 'of', 'becoming', 'an', 'astronaut', '.']
# ['<', 'eng', '>', 'try', 'to', 'find', 'it', '.']
# ['<', 'eng', '>', 'it', 'tasted', 'sweet', '.']
# ['<', 'eng', '>', 'yesterday', 'they', 'fired', 'seven', 'employees', '.']
# ['<', 'eng', '>', 'she', 'lives', 'far', 'from', 'there', '.']
# ['<', 'eng', '>', 'i', "'m", 'just', 'curious', '.']
# ['<', 'eng', '>', 'everyone', 'is', 'equal', 'before', 'the', 'law', '.']
# ['<', 'eng', '>', 'a', 'strange', 'man', 'was', 'walking', 'back', 'and', 'forth', 'in', 'front', 'of', 'my', 'house', '.']
# ['<', 'eng', '>', 'the', 'train', 'for', 'birmingham', 'leaves', 'from', 'platform', '3', '.']
# ['<', 'eng', '>', 'she', 'likes', 'to', 'dress', 'in', 'an', 'old-fashioned', 'way', '.']
# ['<', 'eng', '>', 'this', 'is', 'all', 'the', 'money', 'i', 'have', '.']
# ['<', 'eng', '>', 'the', 'prices', 'of', 'certain', 'foods', 'vary', 'from', 'week', 'to', 'week', '.']
# ['<', 'eng', '>', 'i', 'tried', 'to', 'write', 'with', 'my', 'left', 'hand', '.']
# ['<', 'eng', '>', 'if', 'any', 'harm', 'comes', 'to', 'her', ',', 'i', 'will', 'hold', 'you', 'personally', 'responsible', '.']
# ['<', 'eng', '>', 'tom', 'double-checked', 'his', 'door', 'to', 'make', 'sure', 'it', 'was', 'locked', '.']
# ['<', 'eng', '>', 'the', 'baby', 'is', 'crawling', '.']
# ['<', 'eng', '>', 'the', 'festival', 'starts', 'october', '20th', '.']
# ['<', 'eng', '>', 'tom', 'is', 'extremely', 'busy', 'now', '.']
# ['<', 'eng', '>', 'tom', 'realized', 'something', 'was', "n't", 'right', '.']
# ['<', 'eng', '>', 'her', 'kindness', 'gave', 'me', 'a', 'lump', 'in', 'my', 'throat', '.']
# ['<', 'eng', '>', 'tom', 'and', 'mary', 'do', "n't", 'go', 'to', 'the', 'movies', 'very', 'often', '.']
# ['<', 'eng', '>', 'we', 'have', 'two', 'dogs', ',', 'three', 'cats', ',', 'and', 'six', 'chickens', '.']
# ['<', 'eng', '>', 'i', 'do', "n't", 'want', 'to', 'get', 'in', 'trouble', '.']
# ['<', 'eng', '>', 'belgium', 'is', 'not', 'as', 'large', 'as', 'france', '.']
# ['<', 'eng', '>', 'her', 'smile', 'expressed', 'her', 'thanks', '.']
# ['<', 'eng', '>', 'they', 'are', 'my', 'classmates', '.']
# ['<', 'eng', '>', 'it', "'s", 'dangerous', 'to', 'live', 'near', 'a', 'volcano', '.']
# ['<', 'eng', '>', 'you', 'can', 'say', 'whatever', 'you', 'want', '.']
# ['<', 'eng', '>', 'the', 'music', 'stopped', 'for', 'a', 'minute', '.']
# ['<', 'eng', '>', 'i', "'ll", 'kill', 'you', '.']
# ['<', 'eng', '>', 'tom', 'is', 'a', 'very', 'strange', 'person', '.']
# ['<', 'eng', '>', 'i', 'ca', "n't", 'think', 'of', 'his', 'name', '.']
# ['<', 'eng', '>', 'they', 'heard', 'him', 'come', 'downstairs', '.']
# ['<', 'eng', '>', 'we', 'ca', "n't", 'compete', 'with', 'that', '.']
# ['<', 'eng', '>', 'please', 'send', 'me', 'a', 'picture', 'of', 'yourself', '.']
# ['<', 'eng', '>', 'i', "'d", 'rather', 'walk', '.']
# ['<', 'eng', '>', 'are', 'you', 'for', 'or', 'against', 'the', 'proposal', '?']
# ['<', 'eng', '>', 'i', 'assumed', 'that', 'she', 'was', 'there', '.']
# ['<', 'eng', '>', 'i', 'do', "n't", 'want', 'to', 'run', 'into', 'tom', '.']
# ['<', 'eng', '>', 'tom', 'asked', 'mary', 'if', 'she', 'had', 'been', 'to', 'boston', '.']
# ['<', 'eng', '>', 'i', 'was', 'born', 'during', 'the', 'cold', 'war', '.']
# ['<', 'eng', '>', 'he', 'was', 'deaf', 'to', 'my', 'pleas', '.']
# ['<', 'eng', '>', 'i', 'have', "n't", 'thought', 'about', 'it', 'at', 'all', '.']
# ['<', 'eng', '>', 'i', 'was', 'busy', 'all', 'day', '.']
# ['<', 'eng', '>', 'he', 'betrayed', 'my', 'confidence', '.']
# ['<', 'eng', '>', 'we', 'are', 'decorating', 'the', 'conference', 'room', '.']
# ['<', 'eng', '>', 'get', 'down', 'from', 'there', '.']
# ['<', 'eng', '>', 'he', 'drank', 'it', 'in', 'one', 'gulp', '.']
# ['<', 'eng', '>', 'what', "'s", 'tom', 'going', 'to', 'say', 'about', 'that', '?']
# ['<', 'eng', '>', 'i', 'have', "n't", 'finished', 'reading', 'this', 'book', '.']
# ['<', 'eng', '>', 'tom', 'will', 'be', 'bored', 'stiff', '.']
# ['<', 'eng', '>', 'this', 'article', 'is', 'misleading', '.']
# ['<', 'eng', '>', 'i', 'miss', 'boston', 'so', 'much', '.']
# ['<', 'eng', '>', 'i', 'want', 'to', 'get', 'married', 'and', 'i', 'want', 'to', 'have', 'kids', '.']
# ['<', 'eng', '>', 'in', 'which', 'folder', 'did', 'you', 'save', 'the', 'file', '?']
# ['<', 'eng', '>', 'tom', 'is', 'allergic', 'to', 'cats', '.']
# ['<', 'eng', '>', 'i', "'m", 'a', 'foreigner', 'and', 'i', 'do', "n't", 'know', 'czech', 'very', 'well', '.', 'please', ',', 'speak', 'slowly', '.']
# ['<', 'eng', '>', 'we', 'go', 'tomorrow', '.']
# ['<', 'eng', '>', 'put', 'some', 'more', 'wood', 'on', 'the', 'fire', '.']
# ['<', 'eng', '>', 'we', "'re", 'making', 'plans', 'for', 'the', 'holidays', '.']
# ['<', 'eng', '>', 'it', 'was', 'like', 'that', '.']
# ['<', 'eng', '>', 'it', "'s", 'very', 'unlikely', 'that', 'we', 'will', 'ever', 'find', 'a', 'solution', 'to', 'this', 'problem', '.']
# ['<', 'eng', '>', 'which', 'is', 'mine', '?']
# ['<', 'eng', '>', 'tom', 'lost', 'consciousness', '.']
# ['<', 'eng', '>', 'i', 'forgot', 'to', 'buy', 'the', 'textbook', '.']
# ['<', 'eng', '>', 'they', 'must', "'ve", 'made', 'a', 'mistake', '.']
# ['<', 'eng', '>', 'the', 'morale', 'of', 'those', 'men', 'was', 'excellent', '.']
# ['<', 'eng', '>', 'my', 'life', 'is', 'falling', 'apart', '.']
# ['<', 'eng', '>', 'without', 'his', 'glasses', ',', 'he', 'is', 'as', 'blind', 'as', 'a', 'bat', '.']
# ['<', 'eng', '>', 'do', 'what', 'you', 'want', '.']
# ['<', 'eng', '>', 'i', 'always', 'drive', 'under', 'the', 'speed', 'limit', '.']
# ['<', 'eng', '>', 'tom', 'and', 'i', 'helped', 'each', 'other', '.']
# ['<', 'eng', '>', 'i', "'ll", 'try', 'to', 'memorize', 'it', '.']
# ['<', 'eng', '>', 'you', 'ought', 'not', 'to', 'have', 'spent', 'so', 'much', 'money', 'on', 'your', 'hobby', '.']
# ['<', 'eng', '>', 'hideyo', 'noguchi', 'was', 'a', 'great', 'man', '.']
# ['<', 'eng', '>', 'tom', 'and', 'i', 'live', 'together', '.']
# ['<', 'eng', '>', 'do', 'you', 'play', 'the', 'guitar', '?']
# ['<', 'eng', '>', 'there', 'is', 'an', 'urgent', 'need', 'for', 'them', 'to', 'update', 'their', 'system', '.']
# ['<', 'eng', '>', 'this', 'tea', 'is', 'very', 'hot', '.']
# ['<', 'eng', '>', 'i', 'think', 'that', 'i', 'drank', 'too', 'much', '.']
# ['<', 'eng', '>', 'i', "'m", 'kind', 'of', 'sleepy', ',', 'too', '.']
# ['<', 'eng', '>', 'i', 'thought', 'you', 'might', 'want', 'something', 'to', 'drink', '.']
# ['<', 'eng', '>', 'i', 'have', "n't", 'decided', 'which', 'job', 'to', 'apply', 'for', '.']
# ['<', 'eng', '>', 'his', 'car', 'collided', 'with', 'a', 'train', '.']
# ['<', 'eng', '>', 'i', 'am', 'a', 'student', 'at', 'hyogo', 'university', '.']
# ['<', 'eng', '>', 'i', 'assume', 'your', 'party', 'was', 'a', 'success', '.']
# ['<', 'eng', '>', 'not', 'everyone', 'likes', 'that', 'book', '.']
# ['<', 'eng', '>', 'she', 'has', 'lunch', 'at', 'home', '.']
# ['<', 'eng', '>', 'we', 'visited', 'nikko', 'the', 'next', 'day', '.']
# ['<', 'eng', '>', 'i', "'m", 'here', 'for', 'a', 'meeting', '.']
# ['<', 'eng', '>', 'they', 'are', 'the', 'only', 'students', 'who', 'study', 'chinese', '.']
# ['<', 'eng', '>', 'it', 'is', 'a', 'good', 'idea', 'to', 'read', 'this', 'book', '.']
# ['<', 'eng', '>', 'i', 'still', 'love', 'you', '.']
# ['<', 'eng', '>', 'the', 'game', 'will', 'be', 'played', 'even', 'if', 'it', 'rains', '.']
# ['<', 'eng', '>', 'for', 'me', ',', 'they', 'are', 'the', 'best', '.']
# ['<', 'eng', '>', 'he', 'showed', 'courage', 'in', 'the', 'face', 'of', 'great', 'danger', '.']
# ['<', 'eng', '>', 'she', 'is', 'an', 'obstinate', 'girl', '.']
# ['<', 'eng', '>', 'the', 'board', 'is', 'about', 'two', 'meters', 'long', '.']
# ['<', 'eng', '>', 'he', 'lived', 'a', 'happy', 'life', '.']
# ['<', 'eng', '>', 'did', 'you', 'get', 'good', 'marks', '?']
# ['<', 'eng', '>', 'my', 'explanation', 'may', 'sound', 'strange', '.']
# ['<', 'eng', '>', 'i', "'m", 'not', 'busy', 'now', '.']
# ['<', 'eng', '>', 'i', "'m", 'not', 'sure', 'if', 'it', "'s", 'a', 'boy', 'or', 'a', 'girl', '.']
# ['<', 'eng', '>', 'he', 'was', 'born', 'in', 'the', '19th', 'century', '.']
# ['<', 'eng', '>', 'tom', 'is', 'deeply', 'in', 'love', 'with', 'mary', '.']
# ['<', 'eng', '>', 'i', "'m", 'still', 'married', 'to', 'tom', '.']
# ['<', 'eng', '>', 'i', 'love', 'playing', 'solitaire', '.']
# ['<', 'eng', '>', 'did', 'tom', 'yell', 'at', 'mary', '?']
# ['<', 'eng', '>', 'is', 'it', 'ok', 'if', 'i', 'sit', 'here', '?']
# ['<', 'eng', '>', 'how', 'can', 'i', 'get', 'to', 'the', 'station', '?']
# ['<', 'eng', '>', 'people', 'living', 'in', 'town', 'do', "n't", 'know', 'the', 'pleasures', 'of', 'country', 'life', '.']
# ['<', 'eng', '>', 'write', 'down', 'your', 'date', 'of', 'birth', 'here', '.']
# ['<', 'eng', '>', 'i', 'do', "n't", 'want', 'to', 'be', 'up', 'all', 'night', '.']
# ['<', 'eng', '>', 'the', 'soldiers', 'returned', 'to', 'their', 'lines', '.']
# ['<', 'eng', '>', 'i', 'thought', 'it', 'was', 'hilarious', '.']
# ['<', 'eng', '>', 'time', 'travel', 'is', 'impossible', '.']
# ['<', 'eng', '>', 'we', 'would', 'like', 'to', 'visit', 'nikko', 'during', 'this', 'summer', 'vacation', '.']
# ['<', 'eng', '>', 'they', "'ll", 'be', 'safe', 'here', '.']
# ['<', 'eng', '>', 'tom', 'picked', 'up', 'that', 'habit', 'from', 'his', 'father', '.']
# ['<', 'eng', '>', 'are', 'you', 'one', 'of', 'tom', "'s", 'relatives', '?']
# ['<', 'eng', '>', 'tom', 'laughed', '.']
# ['<', 'eng', '>', 'i', 'am', 'thrilled', 'to', 'be', 'here', '.']
# ['<', 'eng', '>', 'not', 'a', 'single', 'person', 'arrived', 'late', '.']
# ['<', 'eng', '>', 'tom', 'has', 'two', 'jobs', '.']
# ['<', 'eng', '>', 'you', "'re", 'an', 'overly', 'optimistic', 'girl', '.']
# ['<', 'eng', '>', 'i', 'ca', "n't", 'believe', 'i', 'forgot', 'about', 'that', '.']
# ['<', 'eng', '>', 'tom', 'has', 'two', 'choices', '.']
# ['<', 'eng', '>', 'tom', 'must', 'have', 'spent', 'a', 'fortune', '.']
# ['<', 'eng', '>', 'many', 'people', 'use', 'cash', 'machines', 'to', 'withdraw', 'money', '.']
# ['<', 'eng', '>', 'i', 'see', 'no', 'reason', 'to', 'stop', '.']
# ['<', 'eng', '>', 'somebody', 'messed', 'up', '.']
# ['<', 'eng', '>', 'what', "'s", 'your', 'favorite', 'fast', 'food', 'restaurant', '?']
# ['<', 'eng', '>', 'the', 'tumor', 'was', 'removed', '.']
# ['<', 'eng', '>', 'we', 'are', 'dozing', 'off', '.']
# ['<', 'eng', '>', 'i', "'d", 'like', 'to', 'introduce', 'to', 'you', 'the', 'gentleman', 'i', 'told', 'you', 'about', 'the', 'other', 'day', '.']
# ['<', 'eng', '>', 'tom', 'is', 'at', 'home', 'almost', 'every', 'evening', '.']
# ['<', 'eng', '>', 'do', 'you', 'know', 'where', 'tom', 'was', 'hiding', '?']
# ['<', 'eng', '>', 'it', "'s", 'not', 'as', 'simple', 'as', 'all', 'that', '.']
# ['<', 'eng', '>', 'i', 'especially', 'like', 'the', 'smell', 'of', 'lilacs', '.']
# ['<', 'eng', '>', 'do', "n't", 'you', 'agree', ',', 'tom', '?']
# ['<', 'eng', '>', 'the', 'pilot', 'described', 'the', 'scene', 'in', 'detail', '.']
# ['<', 'eng', '>', 'he', 'never', 'seemed', 'to', 'accomplish', 'anything', '.']
# ['<', 'eng', '>', 'it', 'does', "n't", 'exist', '.']
# ['<', 'eng', '>', 'he', 'divorced', 'her', 'after', 'years', 'of', 'unhappiness', '.']
# ['<', 'eng', '>', 'i', 'received', 'a', 'letter', 'written', 'one', 'week', 'ago', '.']
# ['<', 'eng', '>', 'i', 'was', 'afraid', 'of', 'that', '.']
# ['<', 'eng', '>', 'i', "'m", 'starved', '.']
# ['<', 'eng', '>', 'tom', 'is', 'watching', 'beach', 'volleyball', '.']
# ['<', 'eng', '>', 'i', 'would', 'like', 'to', 'leave', 'this', 'town', 'and', 'never', 'come', 'back', '.']
# ['<', 'eng', '>', 'the', 'peacock', "'s", 'beautiful', 'tail', 'helps', 'it', 'attract', 'females', '.']
# ['<', 'eng', '>', 'tom', 'stood', 'there', 'for', 'a', 'while', '.']
# ['<', 'eng', '>', 'let', "'s", 'eat', 'lunch', 'outside', '.']
# ['<', 'eng', '>', 'i', 'do', "n't", 'want', 'that', 'one', '.']
# ['<', 'eng', '>', 'here', 'you', 'are', '.']
# ['<', 'eng', '>', 'it', "'s", 'been', 'a', 'while', ',', 'has', "n't", 'it', '?']
# ['<', 'eng', '>', 'at', 'what', 'heat', 'should', 'i', 'cook', 'this', '?']
# ['<', 'eng', '>', 'you', "'re", 'the', 'best', '.']
# ['<', 'eng', '>', 'i', 'saw', 'the', 'old', 'man', 'feed', 'his', 'dog', 'chicken', 'bones', '.']
# ['<', 'eng', '>', 'obey', 'your', 'teachers', '.']
# ...
# ['<', 'eng', '>', 'why', 'did', 'you', 'turn', 'down', 'his', 'offer', '?']
# ['<', 'eng', '>', 'is', 'this', 'diamond', 'real', '?']
# ['<', 'eng', '>', 'my', 'father', 'grew', 'old', '.']
# ['<', 'eng', '>', 'tom', 'was', 'merely', 'a', 'witness', '.']
# ['<', 'eng', '>', 'i', 'do', "n't", 'know', 'exactly', 'where', 'i', 'was', 'born', '.']
# ['<', 'eng', '>', 'tom', 'was', 'arrested', 'and', 'charged', 'with', 'the', 'murder', '.']
# ['<', 'eng', '>', 'this', 'company', 'manufactures', 'computer', 'chips', '.']
# ['<', 'eng', '>', 'it', 'is', 'risky', 'for', 'you', 'to', 'go', 'into', 'that', 'area', 'alone', '.']
# ['<', 'eng', '>', 'what', 'nonsense', '!']
# ['<', 'eng', '>', 'my', 'grandmother', 'speaks', 'slowly', '.']
# ['<', 'eng', '>', 'i', 'can', 'not', 'even', 'boil', 'water', ',', 'much', 'less', 'roast', 'a', 'turkey', '.']
# ['<', 'eng', '>', 'tom', "'s", 'wife', 'would', 'probably', 'leave', 'him', 'if', 'she', 'knew', 'the', 'truth', '.']
# ['<', 'eng', '>', 'it', "'s", 'the', 'best', 'thing', 'that', 'ever', 'happened', 'to', 'me', '.']
# ['<', 'eng', '>', 'feeding', 'pigeons', 'is', 'prohibited', '.']
# ['<', 'eng', '>', 'when', 'spring', 'comes', ',', 'it', 'gets', 'warm', '.']
# ['<', 'eng', '>', 'i', 'do', "n't", 'want', 'to', 'sue', 'tom', '.']
# ['<', 'eng', '>', 'eat', 'everything', 'on', 'your', 'plate', '.']
# ['<', 'eng', '>', 'tom', 'ran', 'out', 'of', 'water', '.']
# ['<', 'eng', '>', 'tom', 'has', 'trouble', 'judging', 'distances', '.']
# ['<', 'eng', '>', 'across', 'the', 'street', 'there', "'s", 'a', 'white', 'house', '.']
# ['<', 'eng', '>', 'i', 'am', 'no', 'better', 'than', 'a', 'beggar', '.']
# ['<', 'eng', '>', 'which', 'wire', 'should', 'i', 'cut', ',', 'the', 'red', 'one', 'or', 'the', 'white', 'one', '?']
# ['<', 'eng', '>', 'get', 'out', 'of', 'here', 'immediately', '!']
# ['<', 'eng', '>', 'tom', 'was', 'alone', 'most', 'of', 'the', 'time', '.']
# ['<', 'eng', '>', 'why', 'do', 'you', 'always', 'speak', 'to', 'me', 'in', 'english', '?', 'is', 'it', 'because', 'i', "'m", 'a', 'foreigner', '?']
# ['<', 'eng', '>', 'i', 'have', 'a', 'glass', 'eye', '.']
# ['<', 'eng', '>', 'tom', 'might', 'be', 'wrong', '.']
# ['<', 'eng', '>', 'tom', 'showed', 'his', 'courage', 'in', 'the', 'face', 'of', 'danger', '.']
# ['<', 'eng', '>', 'the', 'typical', 'japanese', 'person', 'does', "n't", 'speak', 'english', '.']
# ['<', 'eng', '>', 'that', "'s", 'what', 'i', 'said', 'all', 'along', '.']
# ['<', 'eng', '>', 'i', 'hate', 'birthday', 'parties', '.']
# ['<', 'eng', '>', 'are', 'you', 'hot', '?']
# ['<', 'eng', '>', 'you', 'have', 'a', 'beautiful', 'voice', '.']
# ['<', 'eng', '>', 'that', 'was', 'what', 'tom', 'told', 'mary', '.']
# ['<', 'eng', '>', 'tom', 'is', 'a', 'scientist', '.']
# ['<', 'eng', '>', 'i', "'ve", 'been', 'waiting', 'for', 'this', 'day', 'to', 'come', '.']
# ['<', 'eng', '>', 'the', 'detective', 'disguised', 'himself', 'as', 'an', 'old', 'gentleman', '.']
# ['<', 'eng', '>', '``', 'have', 'you', 'ever', 'been', 'to', 'new', 'york', '?', "''", '``', 'yes', ',', 'i', "'ve", 'been', 'there', 'a', 'couple', 'of', 'times', '.', "''"]
# ['<', 'eng', '>', 'why', 'are', 'dogs', 'easier', 'to', 'train', 'than', 'cats', '?']
# ['<', 'eng', '>', 'i', 'got', 'some', 'money', 'from', 'a', 'cash', 'machine', '.']
# ['<', 'eng', '>', 'not', 'all', 'policemen', 'are', 'brave', '.']
# ['<', 'eng', '>', 'i', 'know', 'it', 'does', "n't", 'make', 'sense', '.']
# ['<', 'eng', '>', 'i', 'left', 'the', 'window', 'open', '.']
# ['<', 'eng', '>', 'he', 'looks', 'kind', 'of', 'pale', '.']
# ['<', 'eng', '>', 'it', "'s", 'not', 'the', 'same', '.']
# ['<', 'eng', '>', 'i', 'did', 'something', 'similar', '.']
# ['<', 'eng', '>', 'there', 'is', "n't", 'much', 'furniture', 'in', 'my', 'house', '.']
# ['<', 'eng', '>', 'you', 'know', 'what', 'needs', 'to', 'be', 'done', '.']
# ['<', 'eng', '>', 'tom', 'passed', 'away', 'last', 'night', '.']
# ['<', 'eng', '>', 'who', 'was', 'it', 'that', 'bought', 'this', 'skirt', 'yesterday', '?']
# ['<', 'eng', '>', 'my', 'mother', 'is', 'writing', 'a', 'letter', 'now', '.']
# ['<', 'eng', '>', 'it', "'s", 'very', 'simple', '.']
# ['<', 'eng', '>', 'his', 'failure', 'led', 'him', 'to', 'drink', 'every', 'night', '.']
# ['<', 'eng', '>', 'tom', 'found', 'a', 'few', 'good', 'deals', 'at', 'the', 'flea', 'market', '.']
# ['<', 'eng', '>', 'tom', 'is', "n't", 'budging', 'on', 'this', 'one', '.']
# ['<', 'eng', '>', 'how', "'s", 'your', 'father', '?']
# ['<', 'eng', '>', 'death', 'is', 'often', 'compared', 'to', 'sleep', '.']
# ['<', 'eng', '>', 'how', 'was', 'the', 'wedding', '?']
# ['<', 'eng', '>', 'tom', 'starts', 'work', 'on', 'monday', '.']
# ['<', 'eng', '>', 'i', 'have', 'to', 'be', 'there', '.']
# ['<', 'eng', '>', 'we', 'moved', 'into', 'a', 'new', 'house', '.']
# ['<', 'eng', '>', 'do', "n't", 'let', 'tom', 'run', 'away', '.']
# ['<', 'eng', '>', 'death', 'is', 'an', 'integral', 'part', 'of', 'life', '.']
# ['<', 'eng', '>', 'queen', 'elizabeth', 'died', 'in', '1603', '.']
# ['<', 'eng', '>', 'tom', 'wants', 'to', 'see', 'mary', 'again', '.']
# ['<', 'eng', '>', 'the', 'race', 'was', 'fixed', '.']
# ['<', 'eng', '>', 'i', 'will', 'be', 'back', 'by', 'nine', '.']
# ['<', 'eng', '>', 'would', 'you', 'mind', 'me', 'smoking', 'here', '?']
# ['<', 'eng', '>', 'i', 'had', 'a', 'great', 'time', 'here', '.']
# ['<', 'eng', '>', 'how', 'old', 'is', 'your', 'dog', '?']
# ['<', 'eng', '>', 'try', 'it', 'out', 'yourself', '.']
# ['<', 'eng', '>', 'what', 'prevented', 'him', 'from', 'coming', '?']
# ['<', 'eng', '>', 'i', 'need', 'a', 'moment', 'of', 'your', 'time', '.']
# ['<', 'eng', '>', 'we', 'do', "n't", 'need', 'anything', '.']
# ['<', 'eng', '>', 'am', 'i', 'safe', 'here', '?']
# ['<', 'eng', '>', 'at', 'first', ',', 'i', 'thought', 'she', 'was', 'sick', '.']
# ['<', 'eng', '>', 'tom', 'is', 'going', 'to', 'be', 'punished', 'for', 'what', 'he', 'did', '.']
# ['<', 'eng', '>', 'i', 'like', 'to', 'chew', 'tobacco', '.']
# ['<', 'eng', '>', 'if', 'i', 'could', 'have', 'a', 'wish', ',', 'i', "'d", 'wish', 'i', 'could', 'make', 'up', 'for', 'lost', 'time', '.']
# ['<', 'eng', '>', 'work', 'while', 'you', 'work', ',', 'play', 'while', 'you', 'play', '.']
# ['<', 'eng', '>', 'tom', 'knew', 'that', 'mary', 'could', "n't", 'be', 'trusted', '.']
# ['<', 'eng', '>', 'i', "'m", 'too', 'tired', 'to', 'concentrate', 'on', 'this', 'problem', 'right', 'now', '.']
# ['<', 'eng', '>', 'they', "'re", 'worried', '.']
# ['<', 'eng', '>', 'give', 'it', 'to', 'anyone', 'you', 'like', '.']
# ['<', 'eng', '>', 'my', 'friend', 'only', 'eats', 'organic', 'food', '.']
# ['<', 'eng', '>', 'this', 'discussion', 'is', 'over', '.']
# ['<', 'eng', '>', 'tell', 'tom', 'hi', 'for', 'me', '.']
# ['<', 'eng', '>', 'i', 'have', "n't", 'read', 'his', 'novel', ',', 'and', 'my', 'brother', 'has', "n't", 'either', '.']
# ['<', 'eng', '>', 'he', 'will', 'pay', 'for', 'everything', '.']
# ['<', 'eng', '>', 'look', 'at', 'that', 'pole', 'in', 'the', 'square', '.']
# ['<', 'eng', '>', 'we', "'re", 'almost', 'ready', '.']
# ['<', 'eng', '>', 'how', 'did', 'tom', 'escape', '?']
# ['<', 'eng', '>', 'read', 'the', 'bottom', 'of', 'the', 'page', '.']
# ['<', 'eng', '>', 'i', "'ve", 'got', 'to', 'get', 'some', 'sleep', '.']
# ['<', 'eng', '>', 'did', 'anybody', 'get', 'hurt', '?']
# ['<', 'eng', '>', 'the', 'flu', 'prevented', 'him', 'from', 'playing', 'golf', '.']
# ['<', 'eng', '>', 'tom', 'should', 'apply', 'for', 'this', 'job', '.']
# ['<', 'eng', '>', 'i', 'do', "n't", 'like', 'telling', 'you', 'the', 'truth', '.']
# ['<', 'eng', '>', 'tom', 'has', 'gambling', 'debts', '.']
# ['<', 'eng', '>', 'tom', 'loves', 'sports', '.']
# ['<', 'eng', '>', 'you', 'promised', '.']
# ['<', 'eng', '>', 'i', 'feel', 'a', 'little', 'weak', 'today', '.']
# ['<', 'eng', '>', 'you', 'should', 'turn', 'off', 'the', 'light', 'before', 'going', 'to', 'sleep', '.']
# ['<', 'eng', '>', 'come', 'out', 'here', '.']
# ['<', 'eng', '>', 'country', 'people', 'are', 'traditionally', 'suspicious', 'of', 'strangers', '.']
# ['<', 'eng', '>', 'they', 'had', 'a', 'brief', 'date', '.']
# ['<', 'eng', '>', 'what', 'can', 'you', 'do', 'for', 'me', '?']
# ['<', 'eng', '>', 'he', 'said', 'he', 'would', 'go', 'to', 'the', 'united', 'states', '.']
# ['<', 'eng', '>', 'this', 'tv', 'was', 'made', 'in', 'china', '.']
# ['<', 'eng', '>', 'you', 'should', 'have', 'stayed', 'in', 'the', 'car', '.']
# ['<', 'eng', '>', 'how', 'long', 'will', 'this', 'cold', 'weather', 'last', '?']
# ['<', 'eng', '>', 'this', 'dog', 'eats', 'almost', 'anything', '.']
# ['<', 'eng', '>', 'we', 'wo', "n't", 'be', 'able', 'to', 'escape', '.']
# ['<', 'eng', '>', 'that', "'s", 'all', 'i', 'have', 'to', 'say', '.']
# ['<', 'eng', '>', 'i', 'take', 'vitamins', 'every', 'day', '.']
# ['<', 'eng', '>', 'my', 'father', 'likes', 'pizza', 'very', 'much', '.']
# ['<', 'eng', '>', 'have', 'you', 'read', 'today', "'s", 'paper', 'yet', '?']
# ['<', 'eng', '>', 'it', "'ll", 'be', 'a', 'big', 'occasion', '.']
# ['<', 'eng', '>', 'i', 'think', 'you', 'know', 'that', "'s", 'not', 'a', 'good', 'idea', '.']
# ['<', 'eng', '>', 'i', 'must', 'live', 'with', 'the', 'consequences', 'of', 'the', 'choices', 'i', "'ve", 'made', '.']
# ['<', 'eng', '>', 'the', 'food', 'at', 'this', 'camp', 'is', 'terrible', '.']
# ['<', 'eng', '>', 'i', "'d", 'be', 'careful', '.']
# ['<', 'eng', '>', 'we', 'have', 'run', 'out', 'of', 'gas', '.']
# ['<', 'eng', '>', 'if', 'you', 'knew', ',', 'you', "'d", 'tell', 'me', ',', 'would', "n't", 'you', '?']
# ['<', 'eng', '>', 'help', 'yourself', 'to', 'more', 'cookies', '.']
# ['<', 'eng', '>', 'for', 'all', 'i', 'know', ',', 'he', "'s", 'a', 'criminal', '.']
# ['<', 'eng', '>', 'mary', 'is', 'a', 'very', 'beautiful', 'and', 'interesting', 'woman', '.']
# ['<', 'eng', '>', 'she', 'was', 'brave', '.']
# ['<', 'eng', '>', 'i', 'did', "n't", 'know', 'you', 'were', 'here', '.']
# ['<', 'eng', '>', 'come', 'anytime', '.']
# ['<', 'eng', '>', 'you', 'may', 'swim', '.']
# ['<', 'eng', '>', 'what', 'were', 'they', 'talking', 'about', '?']
# ['<', 'eng', '>', 'i', "'m", 'sure', 'that', 'you', 'will', 'succeed', '.']
# ['<', 'eng', '>', 'do', 'you', 'drink', 'green', 'tea', '?']
# ['<', 'eng', '>', 'tom', 'does', "n't", 'go', 'to', 'his', 'office', 'on', 'saturday', '.']
# ['<', 'eng', '>', 'you', "'re", 'a', 'beautiful', 'young', 'woman', '.']
# ['<', 'eng', '>', 'they', 'took', 'him', 'to', 'the', 'hospital', 'for', 'his', 'fever', '.']
# ['<', 'eng', '>', 'yesterday', 'was', 'the', 'last', 'day', 'of', 'school', '.']
# ['<', 'eng', '>', 'that', "'s", 'a', 'great', 'idea', '.']
# ['<', 'eng', '>', 'it', 'was', 'fantastic', '.']
# ['<', 'eng', '>', 'you', "'re", 'pretty', 'good', 'at', 'this', '.']
# ['<', 'eng', '>', 'this', 'never', 'happened', '.']
# ['<', 'eng', '>', 'this', 'is', 'a', 'restricted', 'area', '.']
# ['<', 'eng', '>', 'i', 'do', "n't", 'even', 'have', 'time', 'to', 'read', '.']
# ['<', 'eng', '>', 'how', 'many', 'languages', 'do', 'you', 'speak', 'well', '?']
# ['<', 'eng', '>', 'i', 'have', 'a', 'lot', 'to', 'do', 'today', '.']
# ['<', 'eng', '>', 'we', 'think', 'the', 'reason', 'for', 'his', 'success', 'was', 'because', 'of', 'hard', 'work', '.']
# ['<', 'eng', '>', 'this', 'fruit', 'is', "n't", 'for', 'you', '.']
# ['<', 'eng', '>', 'you', 'must', 'be', 'more', 'polite', '.']
# ['<', 'eng', '>', 'there', 'seems', 'to', 'be', 'a', 'mistake', '.']
# ['<', 'eng', '>', 'you', "'re", 'mean', '.']
# ['<', 'eng', '>', 'tom', 'does', "n't", 'believe', 'anything', 'mary', 'says', '.']
# ['<', 'eng', '>', 'she', 'told', 'me', 'an', 'interesting', 'story', '.']
# ['<', 'eng', '>', 'tom', 'beeped', 'the', 'horn', '.']
# ['<', 'eng', '>', 'all', 'humanity', 'will', 'suffer', 'if', 'a', 'nuclear', 'war', 'breaks', 'out', '.']
# ['<', 'eng', '>', 'i', "'ve", 'got', 'to', 'stop', 'eating', 'such', 'sweet', 'ice', 'cream', '.']
# ['<', 'eng', '>', 'ca', "n't", 'we', 'start', 'over', '?']
# ['<', 'eng', '>', 'i', "'ll", 'let', 'you', 'know', 'when', 'we', 'come', 'to', 'the', 'station', '.']
# ['<', 'eng', '>', 'what', 'do', 'you', 'see', 'in', 'the', 'picture', '?']
# ['<', 'eng', '>', 'father', 'is', 'well', 'as', 'usual', '.']
# ['<', 'eng', '>', 'how', 'long', 'have', 'you', 'been', 'in', 'boston', '?']
# ['<', 'eng', '>', 'she', 'has', 'two', 'cats', '.', 'one', 'is', 'white', 'and', 'one', 'is', 'black', '.']
# ['<', 'eng', '>', 'slow', 'down', '.']
# ['<', 'eng', '>', 'he', 'had', 'an', 'operation', 'on', 'his', 'left', 'leg', '.']
# ['<', 'eng', '>', 'i', 'know', 'where', 'you', 'live', '.']
# ['<', 'eng', '>', 'he', 'deemed', 'it', 'wise', 'to', 'accept', 'the', 'offer', '.']
# ['<', 'eng', '>', 'i', 'want', 'to', 'tell', 'you', 'what', 'happened', '.']
# ['<', 'eng', '>', 'now', 'it', 'is', 'my', 'turn', 'to', 'speak', '.']
# ['<', 'eng', '>', 'somebody', 'messed', 'up', '.']
# ['<', 'eng', '>', 'i', 'will', 'quit', 'smoking', 'for', 'good', '.']
# ['<', 'eng', '>', 'nobody', 'is', 'speaking', '.']
# ['<', 'eng', '>', 'i', 'asked', 'tom', '.']
# ['<', 'eng', '>', 'i', 'want', 'to', 'see', 'more', '.']
# ['<', 'eng', '>', 'i', 'know', 'what', "'s", 'at', 'stake', '.']
# ['<', 'eng', '>', 'you', 'are', 'not', 'our', 'friend', '.']
# ['<', 'eng', '>', 'tom', 'teaches', 'me', 'french', 'twice', 'a', 'week', '.']
# ['<', 'eng', '>', 'i', 'am', 'sick', 'and', 'tired', 'of', 'him', '.']
# ['<', 'eng', '>', 'i', 'did', "n't", 'know', 'you', 'were', 'a', 'doctor', '.']
# ['<', 'eng', '>', 'you', 'should', "'ve", 'stood', 'up', '.']
# ['<', 'eng', '>', 'how', 'many', 'schools', 'are', 'there', 'in', 'your', 'city', '?']
# ['<', 'eng', '>', 'i', 'like', 'sweets', '.']
# ['<', 'eng', '>', 'tom', 'needs', 'the', 'money', 'right', 'away', '.']
# ['<', 'eng', '>', 'i', 'like', 'surprises', '.']
# ['<', 'eng', '>', 'they', 'went', 'to', 'the', 'hospital', '.']
# ['<', 'eng', '>', 'we', 'are', 'not', 'alone', '.']
# ['<', 'eng', '>', 'i', 'can', 'barely', 'remember', 'what', 'my', 'grandfather', 'looked', 'like', '.']
# ['<', 'eng', '>', 'the', 'air', 'conditioner', 'is', 'out', 'of', 'order', '.']
# ['<', 'eng', '>', 'i', 'do', "n't", 'now', 'what', 'i', "'m", 'going', 'to', 'do', 'now', '.']
# ['<', 'eng', '>', 'you', 'were', 'late', ',', 'were', "n't", 'you', '?']
# ['<', 'eng', '>', 'i', 'just', 'do', "n't", 'want', 'to', 'go', 'with', 'you', '.']
# ['<', 'eng', '>', 'where', 'do', 'you', 'want', 'it', 'delivered', '?']
# ['<', 'eng', '>', 'in', 'the', 'summer', ',', 'the', 'temperature', 'ranges', 'from', 'thirty', 'to', 'forty', 'degrees', 'celsius', '.']
# ['<', 'eng', '>', 'is', 'lunch', 'included', 'in', 'this', 'price', '?']
# ['<', 'eng', '>', 'what', 'in', 'the', 'world', 'does', 'he', 'mean', '?']
# ['<', 'eng', '>', 'that', 'will', 'be', 'enough', 'for', 'now', '.']
# ['<', 'eng', '>', 'you', 'should', 'assume', 'that', 'tom', 'wo', "n't", 'help', 'us', 'at', 'all', '.']
# ['<', 'eng', '>', 'my', 'cousin', 'is', 'a', 'junkie', '.']
# ['<', 'eng', '>', 'tom', 'invited', 'mary', 'to', 'boston', '.']
# ['<', 'eng', '>', 'please', 'do', "n't", 'do', 'that', 'again', '.']
# ['<', 'eng', '>', 'that', 'white', 'building', 'is', 'a', 'morgue', '.']
# ['<', 'eng', '>', 'without', 'the', 'slightest', 'hesitation', ',', 'he', 'sold', 'his', 'own', 'car', '.']
# ['<', 'eng', '>', 'tom', 'is', 'a', 'wimp', '.']
# ['<', 'eng', '>', 'his', 'daughter', 'ran', 'back', 'to', 'her', 'room', '.']
# ['<', 'eng', '>', 'he', 'put', 'the', 'key', 'on', 'the', 'desk', 'as', 'usual', '.']
# ['<', 'eng', '>', 'we', 'went', 'to', 'the', 'park', ',', 'and', 'we', 'played', 'there', '.']
# ['<', 'eng', '>', 'tom', 'still', 'has', 'feelings', 'for', 'mary', '.']
# ['<', 'eng', '>', 'it', 'was', 'a', 'fascinating', 'story', '.']
# ['<', 'eng', '>', 'tom', 'is', 'the', 'only', 'guy', 'i', 'know', 'from', 'boston', '.']
# ['<', 'eng', '>', 'tell', 'me', 'the', 'reason', 'why', 'he', 'was', 'fired', '.']
# ['<', 'eng', '>', 'tom', 'loves', 'his', 'wife', 'and', 'kids', '.']
# ['<', 'eng', '>', 'do', "n't", 'count', 'on', 'him', 'to', 'lend', 'you', 'any', 'money', '.']
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[143], line 18
#      15 text_en = "Hello, how are you?"
#      17 # Tokenización para el encoder (entrada)
# ---> 18 encoded_input = tokenizer(
#      19     x_train_ingles,
#      20     return_tensors="pt",
#      21     padding=True,
#      22     truncation=True,
#      23     add_special_tokens=False  # incluye <s> y </s> automáticamente
#      24 )
#      26 print("Tokens de entrada:", encoded_input.input_ids)
#      28 # Para el decoder (target), se puede usar el idioma objetivo
#
# File /opt/anaconda3/envs/TFM/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:2887, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2885     if not self._in_target_context_manager:
#    2886         self._switch_to_input_mode()
# -> 2887     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2888 if text_target is not None:
#    2889     self._switch_to_target_mode()
#
# File /opt/anaconda3/envs/TFM/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:2947, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    2944         return False
#    2946 if not _is_valid_text_input(text):
# -> 2947     raise ValueError(
#    2948         "text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) "
#    2949         "or `List[List[str]]` (batch of pretokenized examples)."
#    2950     )
#    2952 if text_pair is not None and not _is_valid_text_input(text_pair):
#    2953     raise ValueError(
#    2954         "text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) "
#    2955         "or `List[List[str]]` (batch of pretokenized examples)."
#    2956     )
#
# ValueError: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
